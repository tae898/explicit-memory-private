# %%
import rdflib
from rdflib.namespace import RDF, XSD, OWL
from typing import Optional

# Load the ontology
ontology_graph = rdflib.Graph()
ontology_graph.parse("ontology.ttl", format="turtle")

# Define the namespace for co_learning (adjust if needed)
CO_LEARNING_NS = rdflib.Namespace("http://example.org/co_learning#")


def validate_class_membership(
    data_graph: rdflib.Graph, class_uri: rdflib.URIRef
) -> bool:
    """
    Validate that all instances claiming to be of a specific class actually belong to
    that class.

    Args:
        data_graph (rdflib.Graph): The graph containing RDF data.
        class_uri (rdflib.URIRef): The URI of the class to check for membership.

    Returns:
        bool: True if all instances belong to the correct class; False if any errors are
        found.
    """
    is_valid = True

    # Check if the class exists in the ontology
    if (class_uri, RDF.type, OWL.Class) not in ontology_graph:
        print(f"Error: Class {class_uri} is not defined in the ontology.")
        return False

    # Check instances of this class in the data graph
    for instance in data_graph.subjects(RDF.type, class_uri):
        if not data_graph.triples((instance, RDF.type, class_uri)):
            print(f"Error: {instance} claims to be of unknown class {class_uri}")
            is_valid = False

    return is_valid


def validate_domain_range(
    data_graph: rdflib.Graph,
    property_uri: rdflib.URIRef,
    domain_uri: rdflib.URIRef,
    range_uri: rdflib.URIRef,
) -> bool:
    """
    Validate that a property is used correctly according to the ontology's domain and
    range.

    Args:
        data_graph (rdflib.Graph): The graph containing RDF data.
        property_uri (rdflib.URIRef): The URI of the property to validate.
        domain_uri (rdflib.URIRef): The URI of the expected domain class.
        range_uri (rdflib.URIRef): The URI of the expected range class.

    Returns:
        bool: True if all properties have correct domain and range; False if any errors
        are found.
    """
    is_valid = True

    for s, o in data_graph.subject_objects(property_uri):
        # Check domain
        if not data_graph.triples((s, RDF.type, domain_uri)):
            print(f"Error: {s} is not of type {domain_uri} for property {property_uri}")
            is_valid = False
        # Check range
        if not data_graph.triples((o, RDF.type, range_uri)):
            print(f"Error: {o} is not of type {range_uri} for property {property_uri}")
            is_valid = False

    return is_valid


def validate_data_property(
    data_graph: rdflib.Graph,
    property_uri: rdflib.URIRef,
    expected_datatype: rdflib.URIRef,
) -> bool:
    """
    Validate that a data property has the correct datatype.

    Args:
        data_graph (rdflib.Graph): The graph containing RDF data.
        property_uri (rdflib.URIRef): The URI of the data property to validate.
        expected_datatype (rdflib.URIRef): The expected datatype (e.g., XSD.integer).

    Returns:
        bool: True if all data properties have the correct datatype; False if any errors
        are found.
    """
    is_valid = True

    for s, o in data_graph.subject_objects(property_uri):
        # Check if the object is a literal and has the expected datatype
        if not (isinstance(o, rdflib.Literal) and o.datatype == expected_datatype):
            print(f"Error: {o} for {property_uri} is not of type {expected_datatype}")
            is_valid = False

    return is_valid


def validate_graph(ttl_file: str) -> bool:
    """
    Validate an RDF graph loaded from a Turtle (.ttl) file against the ontology.

    Args:
        ttl_file (str): Path to the Turtle file to validate.

    Returns:
        bool: True if the graph is valid according to the ontology; False if any errors
        are found.
    """
    # Load the RDF data
    data_graph = rdflib.Graph()
    data_graph.parse(ttl_file, format="turtle")

    is_valid = True

    # Validate class membership for Situation, ActionHuman, ActionRobot
    is_valid &= validate_class_membership(data_graph, CO_LEARNING_NS.Situation)
    is_valid &= validate_class_membership(data_graph, CO_LEARNING_NS.ActionHuman)
    is_valid &= validate_class_membership(data_graph, CO_LEARNING_NS.ActionRobot)

    # Validate object properties (domain and range checks)
    is_valid &= validate_domain_range(
        data_graph,
        CO_LEARNING_NS.hasSituation,
        CO_LEARNING_NS.CollaborationPattern,
        CO_LEARNING_NS.Situation,
    )
    is_valid &= validate_domain_range(
        data_graph,
        CO_LEARNING_NS.hasActionHuman,
        CO_LEARNING_NS.CollaborationPattern,
        CO_LEARNING_NS.ActionHuman,
    )
    is_valid &= validate_domain_range(
        data_graph,
        CO_LEARNING_NS.hasActionRobot,
        CO_LEARNING_NS.CollaborationPattern,
        CO_LEARNING_NS.ActionRobot,
    )

    # Validate data properties (data type checks)
    is_valid &= validate_data_property(data_graph, CO_LEARNING_NS.hasCPNum, XSD.integer)
    is_valid &= validate_data_property(
        data_graph, CO_LEARNING_NS.hasParticipantNumber, XSD.integer
    )
    is_valid &= validate_data_property(
        data_graph, CO_LEARNING_NS.hasCPLabel, XSD.string
    )
    is_valid &= validate_data_property(
        data_graph, CO_LEARNING_NS.hasTimeScore, XSD.integer
    )
    is_valid &= validate_data_property(
        data_graph, CO_LEARNING_NS.hasUnixTimeStamp, XSD.integer
    )

    return is_valid


# Example of running validation for each TTL file in a directory
from glob import glob

for ttl_path in glob("./rdf-data/*.ttl"):
    print(f"Validating: {ttl_path}")
    if validate_graph(ttl_path):
        print(f"{ttl_path} is valid!")
    else:
        print(f"{ttl_path} has validation errors.")
    print("---\n")
# Out:
# Validating: ./rdf-data/077.ttl
# ./rdf-data/077.ttl is valid!
# ---
#
# Validating: ./rdf-data/151.ttl
# ./rdf-data/151.ttl is valid!
# ---
#
# Validating: ./rdf-data/073.ttl
# ./rdf-data/073.ttl is valid!
# ---
#
# Validating: ./rdf-data/152.ttl
# ./rdf-data/152.ttl is valid!
# ---
#
# Validating: ./rdf-data/065.ttl
# ./rdf-data/065.ttl is valid!
# ---
#
# Validating: ./rdf-data/009.ttl
# ./rdf-data/009.ttl is valid!
# ---
#
# Validating: ./rdf-data/008.ttl
# ./rdf-data/008.ttl is valid!
# ---
#
# Validating: ./rdf-data/185.ttl
# ./rdf-data/185.ttl is valid!
# ---
#
# Validating: ./rdf-data/175.ttl
# ./rdf-data/175.ttl is valid!
# ---
#
# Validating: ./rdf-data/158.ttl
# ./rdf-data/158.ttl is valid!
# ---
#
# Validating: ./rdf-data/126.ttl
# ./rdf-data/126.ttl is valid!
# ---
#
# Validating: ./rdf-data/096.ttl
# ./rdf-data/096.ttl is valid!
# ---
#
# Validating: ./rdf-data/169.ttl
# ./rdf-data/169.ttl is valid!
# ---
#
# Validating: ./rdf-data/034.ttl
# ./rdf-data/034.ttl is valid!
# ---
#
# Validating: ./rdf-data/114.ttl
# ./rdf-data/114.ttl is valid!
# ---
#
# Validating: ./rdf-data/132.ttl
# ./rdf-data/132.ttl is valid!
# ---
#
# Validating: ./rdf-data/121.ttl
# ./rdf-data/121.ttl is valid!
# ---
#
# Validating: ./rdf-data/142.ttl
# ./rdf-data/142.ttl is valid!
# ---
#
# Validating: ./rdf-data/063.ttl
# ./rdf-data/063.ttl is valid!
# ---
#
# Validating: ./rdf-data/110.ttl
# ./rdf-data/110.ttl is valid!
# ---
#
# Validating: ./rdf-data/192.ttl
# ./rdf-data/192.ttl is valid!
# ---
#
# Validating: ./rdf-data/115.ttl
# ./rdf-data/115.ttl is valid!
# ---
#
# Validating: ./rdf-data/149.ttl
# ./rdf-data/149.ttl is valid!
# ---
#
# Validating: ./rdf-data/209.ttl
# ./rdf-data/209.ttl is valid!
# ---
#
# Validating: ./rdf-data/202.ttl
# ./rdf-data/202.ttl is valid!
# ---
#
# Validating: ./rdf-data/188.ttl
# ./rdf-data/188.ttl is valid!
# ---
#
# Validating: ./rdf-data/079.ttl
# ./rdf-data/079.ttl is valid!
# ---
#
# Validating: ./rdf-data/189.ttl
# ./rdf-data/189.ttl is valid!
# ---
#
# Validating: ./rdf-data/004.ttl
# ./rdf-data/004.ttl is valid!
# ---
#
# Validating: ./rdf-data/046.ttl
# ./rdf-data/046.ttl is valid!
# ---
#
# Validating: ./rdf-data/195.ttl
# ./rdf-data/195.ttl is valid!
# ---
#
# Validating: ./rdf-data/031.ttl
# ./rdf-data/031.ttl is valid!
# ---
#
# Validating: ./rdf-data/030.ttl
# ./rdf-data/030.ttl is valid!
# ---
#
# Validating: ./rdf-data/062.ttl
# ./rdf-data/062.ttl is valid!
# ---
#
# Validating: ./rdf-data/180.ttl
# ./rdf-data/180.ttl is valid!
# ---
#
# Validating: ./rdf-data/029.ttl
# ./rdf-data/029.ttl is valid!
# ---
#
# Validating: ./rdf-data/001.ttl
# ./rdf-data/001.ttl is valid!
# ---
#
# Validating: ./rdf-data/125.ttl
# ./rdf-data/125.ttl is valid!
# ---
#
# Validating: ./rdf-data/069.ttl
# ./rdf-data/069.ttl is valid!
# ---
#
# Validating: ./rdf-data/066.ttl
# ./rdf-data/066.ttl is valid!
# ---
#
# Validating: ./rdf-data/107.ttl
# ./rdf-data/107.ttl is valid!
# ---
#
# Validating: ./rdf-data/056.ttl
# ./rdf-data/056.ttl is valid!
# ---
#
# Validating: ./rdf-data/100.ttl
# ./rdf-data/100.ttl is valid!
# ---
#
# Validating: ./rdf-data/018.ttl
# ./rdf-data/018.ttl is valid!
# ---
#
# Validating: ./rdf-data/016.ttl
# ./rdf-data/016.ttl is valid!
# ---
#
# Validating: ./rdf-data/124.ttl
# ./rdf-data/124.ttl is valid!
# ---
#
# Validating: ./rdf-data/104.ttl
# ./rdf-data/104.ttl is valid!
# ---
#
# Validating: ./rdf-data/032.ttl
# ./rdf-data/032.ttl is valid!
# ---
#
# Validating: ./rdf-data/078.ttl
# ./rdf-data/078.ttl is valid!
# ---
#
# Validating: ./rdf-data/038.ttl
# ./rdf-data/038.ttl is valid!
# ---
#
# Validating: ./rdf-data/186.ttl
# ./rdf-data/186.ttl is valid!
# ---
#
# Validating: ./rdf-data/070.ttl
# ./rdf-data/070.ttl is valid!
# ---
#
# Validating: ./rdf-data/190.ttl
# ./rdf-data/190.ttl is valid!
# ---
#
# Validating: ./rdf-data/165.ttl
# ./rdf-data/165.ttl is valid!
# ---
#
# Validating: ./rdf-data/094.ttl
# ./rdf-data/094.ttl is valid!
# ---
#
# Validating: ./rdf-data/160.ttl
# ./rdf-data/160.ttl is valid!
# ---
#
# Validating: ./rdf-data/044.ttl
# ./rdf-data/044.ttl is valid!
# ---
#
# Validating: ./rdf-data/091.ttl
# ./rdf-data/091.ttl is valid!
# ---
#
# Validating: ./rdf-data/017.ttl
# ./rdf-data/017.ttl is valid!
# ---
#
# Validating: ./rdf-data/161.ttl
# ./rdf-data/161.ttl is valid!
# ---
#
# Validating: ./rdf-data/166.ttl
# ./rdf-data/166.ttl is valid!
# ---
#
# Validating: ./rdf-data/194.ttl
# ./rdf-data/194.ttl is valid!
# ---
#
# Validating: ./rdf-data/089.ttl
# ./rdf-data/089.ttl is valid!
# ---
#
# Validating: ./rdf-data/084.ttl
# ./rdf-data/084.ttl is valid!
# ---
#
# Validating: ./rdf-data/204.ttl
# ./rdf-data/204.ttl is valid!
# ---
#
# Validating: ./rdf-data/133.ttl
# ./rdf-data/133.ttl is valid!
# ---
#
# Validating: ./rdf-data/097.ttl
# ./rdf-data/097.ttl is valid!
# ---
#
# Validating: ./rdf-data/106.ttl
# ./rdf-data/106.ttl is valid!
# ---
#
# Validating: ./rdf-data/177.ttl
# ./rdf-data/177.ttl is valid!
# ---
#
# Validating: ./rdf-data/045.ttl
# ./rdf-data/045.ttl is valid!
# ---
#
# Validating: ./rdf-data/108.ttl
# ./rdf-data/108.ttl is valid!
# ---
#
# Validating: ./rdf-data/072.ttl
# ./rdf-data/072.ttl is valid!
# ---
#
# Validating: ./rdf-data/111.ttl
# ./rdf-data/111.ttl is valid!
# ---
#
# Validating: ./rdf-data/026.ttl
# ./rdf-data/026.ttl is valid!
# ---
#
# Validating: ./rdf-data/003.ttl
# ./rdf-data/003.ttl is valid!
# ---
#
# Validating: ./rdf-data/119.ttl
# ./rdf-data/119.ttl is valid!
# ---
#
# Validating: ./rdf-data/141.ttl
# ./rdf-data/141.ttl is valid!
# ---
#
# Validating: ./rdf-data/000.ttl
# ./rdf-data/000.ttl is valid!
# ---
#
# Validating: ./rdf-data/137.ttl
# ./rdf-data/137.ttl is valid!
# ---
#
# Validating: ./rdf-data/051.ttl
# ./rdf-data/051.ttl is valid!
# ---
#
# Validating: ./rdf-data/014.ttl
# ./rdf-data/014.ttl is valid!
# ---
#
# Validating: ./rdf-data/143.ttl
# ./rdf-data/143.ttl is valid!
# ---
#
# Validating: ./rdf-data/117.ttl
# ./rdf-data/117.ttl is valid!
# ---
#
# Validating: ./rdf-data/210.ttl
# ./rdf-data/210.ttl is valid!
# ---
#
# Validating: ./rdf-data/039.ttl
# ./rdf-data/039.ttl is valid!
# ---
#
# Validating: ./rdf-data/208.ttl
# ./rdf-data/208.ttl is valid!
# ---
#
# Validating: ./rdf-data/002.ttl
# ./rdf-data/002.ttl is valid!
# ---
#
# Validating: ./rdf-data/035.ttl
# ./rdf-data/035.ttl is valid!
# ---
#
# Validating: ./rdf-data/109.ttl
# ./rdf-data/109.ttl is valid!
# ---
#
# Validating: ./rdf-data/197.ttl
# ./rdf-data/197.ttl is valid!
# ---
#
# Validating: ./rdf-data/033.ttl
# ./rdf-data/033.ttl is valid!
# ---
#
# Validating: ./rdf-data/040.ttl
# ./rdf-data/040.ttl is valid!
# ---
#
# Validating: ./rdf-data/057.ttl
# ./rdf-data/057.ttl is valid!
# ---
#
# Validating: ./rdf-data/171.ttl
# ./rdf-data/171.ttl is valid!
# ---
#
# Validating: ./rdf-data/187.ttl
# ./rdf-data/187.ttl is valid!
# ---
#
# Validating: ./rdf-data/080.ttl
# ./rdf-data/080.ttl is valid!
# ---
#
# Validating: ./rdf-data/193.ttl
# ./rdf-data/193.ttl is valid!
# ---
#
# Validating: ./rdf-data/103.ttl
# ./rdf-data/103.ttl is valid!
# ---
#
# Validating: ./rdf-data/061.ttl
# ./rdf-data/061.ttl is valid!
# ---
#
# Validating: ./rdf-data/155.ttl
# ./rdf-data/155.ttl is valid!
# ---
#
# Validating: ./rdf-data/153.ttl
# ./rdf-data/153.ttl is valid!
# ---
#
# Validating: ./rdf-data/146.ttl
# ./rdf-data/146.ttl is valid!
# ---
#
# Validating: ./rdf-data/182.ttl
# ./rdf-data/182.ttl is valid!
# ---
#
# Validating: ./rdf-data/012.ttl
# ./rdf-data/012.ttl is valid!
# ---
#
# Validating: ./rdf-data/067.ttl
# ./rdf-data/067.ttl is valid!
# ---
#
# Validating: ./rdf-data/049.ttl
# ./rdf-data/049.ttl is valid!
# ---
#
# Validating: ./rdf-data/138.ttl
# ./rdf-data/138.ttl is valid!
# ---
#
# Validating: ./rdf-data/098.ttl
# ./rdf-data/098.ttl is valid!
# ---
#
# Validating: ./rdf-data/136.ttl
# ./rdf-data/136.ttl is valid!
# ---
#
# Validating: ./rdf-data/156.ttl
# ./rdf-data/156.ttl is valid!
# ---
#
# Validating: ./rdf-data/162.ttl
# ./rdf-data/162.ttl is valid!
# ---
#
# Validating: ./rdf-data/082.ttl
# ./rdf-data/082.ttl is valid!
# ---
#
# Validating: ./rdf-data/147.ttl
# ./rdf-data/147.ttl is valid!
# ---
#
# Validating: ./rdf-data/181.ttl
# ./rdf-data/181.ttl is valid!
# ---
#
# Validating: ./rdf-data/053.ttl
# ./rdf-data/053.ttl is valid!
# ---
#
# Validating: ./rdf-data/206.ttl
# ./rdf-data/206.ttl is valid!
# ---
#
# Validating: ./rdf-data/083.ttl
# ./rdf-data/083.ttl is valid!
# ---
#
# Validating: ./rdf-data/196.ttl
# ./rdf-data/196.ttl is valid!
# ---
#
# Validating: ./rdf-data/052.ttl
# ./rdf-data/052.ttl is valid!
# ---
#
# Validating: ./rdf-data/123.ttl
# ./rdf-data/123.ttl is valid!
# ---
#
# Validating: ./rdf-data/135.ttl
# ./rdf-data/135.ttl is valid!
# ---
#
# Validating: ./rdf-data/007.ttl
# ./rdf-data/007.ttl is valid!
# ---
#
# Validating: ./rdf-data/047.ttl
# ./rdf-data/047.ttl is valid!
# ---
#
# Validating: ./rdf-data/122.ttl
# ./rdf-data/122.ttl is valid!
# ---
#
# Validating: ./rdf-data/129.ttl
# ./rdf-data/129.ttl is valid!
# ---
#
# Validating: ./rdf-data/087.ttl
# ./rdf-data/087.ttl is valid!
# ---
#
# Validating: ./rdf-data/025.ttl
# ./rdf-data/025.ttl is valid!
# ---
#
# Validating: ./rdf-data/145.ttl
# ./rdf-data/145.ttl is valid!
# ---
#
# Validating: ./rdf-data/205.ttl
# ./rdf-data/205.ttl is valid!
# ---
#
# Validating: ./rdf-data/116.ttl
# ./rdf-data/116.ttl is valid!
# ---
#
# Validating: ./rdf-data/048.ttl
# ./rdf-data/048.ttl is valid!
# ---
#
# Validating: ./rdf-data/013.ttl
# ./rdf-data/013.ttl is valid!
# ---
#
# Validating: ./rdf-data/134.ttl
# ./rdf-data/134.ttl is valid!
# ---
#
# Validating: ./rdf-data/154.ttl
# ./rdf-data/154.ttl is valid!
# ---
#
# Validating: ./rdf-data/081.ttl
# ./rdf-data/081.ttl is valid!
# ---
#
# Validating: ./rdf-data/074.ttl
# ./rdf-data/074.ttl is valid!
# ---
#
# Validating: ./rdf-data/128.ttl
# ./rdf-data/128.ttl is valid!
# ---
#
# Validating: ./rdf-data/099.ttl
# ./rdf-data/099.ttl is valid!
# ---
#
# Validating: ./rdf-data/011.ttl
# ./rdf-data/011.ttl is valid!
# ---
#
# Validating: ./rdf-data/174.ttl
# ./rdf-data/174.ttl is valid!
# ---
#
# Validating: ./rdf-data/172.ttl
# ./rdf-data/172.ttl is valid!
# ---
#
# Validating: ./rdf-data/207.ttl
# ./rdf-data/207.ttl is valid!
# ---
#
# Validating: ./rdf-data/092.ttl
# ./rdf-data/092.ttl is valid!
# ---
#
# Validating: ./rdf-data/191.ttl
# ./rdf-data/191.ttl is valid!
# ---
#
# Validating: ./rdf-data/041.ttl
# ./rdf-data/041.ttl is valid!
# ---
#
# Validating: ./rdf-data/203.ttl
# ./rdf-data/203.ttl is valid!
# ---
#
# Validating: ./rdf-data/076.ttl
# ./rdf-data/076.ttl is valid!
# ---
#
# Validating: ./rdf-data/088.ttl
# ./rdf-data/088.ttl is valid!
# ---
#
# Validating: ./rdf-data/005.ttl
# ./rdf-data/005.ttl is valid!
# ---
#
# Validating: ./rdf-data/036.ttl
# ./rdf-data/036.ttl is valid!
# ---
#
# Validating: ./rdf-data/163.ttl
# ./rdf-data/163.ttl is valid!
# ---
#
# Validating: ./rdf-data/157.ttl
# ./rdf-data/157.ttl is valid!
# ---
#
# Validating: ./rdf-data/086.ttl
# ./rdf-data/086.ttl is valid!
# ---
#
# Validating: ./rdf-data/167.ttl
# ./rdf-data/167.ttl is valid!
# ---
#
# Validating: ./rdf-data/178.ttl
# ./rdf-data/178.ttl is valid!
# ---
#
# Validating: ./rdf-data/085.ttl
# ./rdf-data/085.ttl is valid!
# ---
#
# Validating: ./rdf-data/105.ttl
# ./rdf-data/105.ttl is valid!
# ---
#
# Validating: ./rdf-data/176.ttl
# ./rdf-data/176.ttl is valid!
# ---
#
# Validating: ./rdf-data/200.ttl
# ./rdf-data/200.ttl is valid!
# ---
#
# Validating: ./rdf-data/170.ttl
# ./rdf-data/170.ttl is valid!
# ---
#
# Validating: ./rdf-data/059.ttl
# ./rdf-data/059.ttl is valid!
# ---
#
# Validating: ./rdf-data/019.ttl
# ./rdf-data/019.ttl is valid!
# ---
#
# Validating: ./rdf-data/130.ttl
# ./rdf-data/130.ttl is valid!
# ---
#
# Validating: ./rdf-data/022.ttl
# ./rdf-data/022.ttl is valid!
# ---
#
# Validating: ./rdf-data/064.ttl
# ./rdf-data/064.ttl is valid!
# ---
#
# Validating: ./rdf-data/164.ttl
# ./rdf-data/164.ttl is valid!
# ---
#
# Validating: ./rdf-data/173.ttl
# ./rdf-data/173.ttl is valid!
# ---
#
# Validating: ./rdf-data/015.ttl
# ./rdf-data/015.ttl is valid!
# ---
#
# Validating: ./rdf-data/140.ttl
# ./rdf-data/140.ttl is valid!
# ---
#
# Validating: ./rdf-data/113.ttl
# ./rdf-data/113.ttl is valid!
# ---
#
# Validating: ./rdf-data/183.ttl
# ./rdf-data/183.ttl is valid!
# ---
#
# Validating: ./rdf-data/027.ttl
# ./rdf-data/027.ttl is valid!
# ---
#
# Validating: ./rdf-data/037.ttl
# ./rdf-data/037.ttl is valid!
# ---
#
# Validating: ./rdf-data/120.ttl
# ./rdf-data/120.ttl is valid!
# ---
#
# Validating: ./rdf-data/060.ttl
# ./rdf-data/060.ttl is valid!
# ---
#
# Validating: ./rdf-data/093.ttl
# ./rdf-data/093.ttl is valid!
# ---
#
# Validating: ./rdf-data/042.ttl
# ./rdf-data/042.ttl is valid!
# ---
#
# Validating: ./rdf-data/043.ttl
# ./rdf-data/043.ttl is valid!
# ---
#
# Validating: ./rdf-data/139.ttl
# ./rdf-data/139.ttl is valid!
# ---
#
# Validating: ./rdf-data/112.ttl
# ./rdf-data/112.ttl is valid!
# ---
#
# Validating: ./rdf-data/021.ttl
# ./rdf-data/021.ttl is valid!
# ---
#
# Validating: ./rdf-data/055.ttl
# ./rdf-data/055.ttl is valid!
# ---
#
# Validating: ./rdf-data/118.ttl
# ./rdf-data/118.ttl is valid!
# ---
#
# Validating: ./rdf-data/028.ttl
# ./rdf-data/028.ttl is valid!
# ---
#
# Validating: ./rdf-data/010.ttl
# ./rdf-data/010.ttl is valid!
# ---
#
# Validating: ./rdf-data/148.ttl
# ./rdf-data/148.ttl is valid!
# ---
#
# Validating: ./rdf-data/023.ttl
# ./rdf-data/023.ttl is valid!
# ---
#
# Validating: ./rdf-data/184.ttl
# ./rdf-data/184.ttl is valid!
# ---
#
# Validating: ./rdf-data/006.ttl
# ./rdf-data/006.ttl is valid!
# ---
#
# Validating: ./rdf-data/068.ttl
# ./rdf-data/068.ttl is valid!
# ---
#
# Validating: ./rdf-data/201.ttl
# ./rdf-data/201.ttl is valid!
# ---
#
# Validating: ./rdf-data/198.ttl
# ./rdf-data/198.ttl is valid!
# ---
#
# Validating: ./rdf-data/090.ttl
# ./rdf-data/090.ttl is valid!
# ---
#
# Validating: ./rdf-data/102.ttl
# ./rdf-data/102.ttl is valid!
# ---
#
# Validating: ./rdf-data/199.ttl
# ./rdf-data/199.ttl is valid!
# ---
#
# Validating: ./rdf-data/071.ttl
# ./rdf-data/071.ttl is valid!
# ---
#
# Validating: ./rdf-data/150.ttl
# ./rdf-data/150.ttl is valid!
# ---
#
# Validating: ./rdf-data/075.ttl
# ./rdf-data/075.ttl is valid!
# ---
#
# Validating: ./rdf-data/127.ttl
# ./rdf-data/127.ttl is valid!
# ---
#
# Validating: ./rdf-data/144.ttl
# ./rdf-data/144.ttl is valid!
# ---
#
# Validating: ./rdf-data/101.ttl
# ./rdf-data/101.ttl is valid!
# ---
#
# Validating: ./rdf-data/054.ttl
# ./rdf-data/054.ttl is valid!
# ---
#
# Validating: ./rdf-data/050.ttl
# ./rdf-data/050.ttl is valid!
# ---
#
# Validating: ./rdf-data/179.ttl
# ./rdf-data/179.ttl is valid!
# ---
#
# Validating: ./rdf-data/020.ttl
# ./rdf-data/020.ttl is valid!
# ---
#
# Validating: ./rdf-data/159.ttl
# ./rdf-data/159.ttl is valid!
# ---
#
# Validating: ./rdf-data/058.ttl
# ./rdf-data/058.ttl is valid!
# ---
#
# Validating: ./rdf-data/095.ttl
# ./rdf-data/095.ttl is valid!
# ---
#
# Validating: ./rdf-data/024.ttl
# ./rdf-data/024.ttl is valid!
# ---
#
# Validating: ./rdf-data/131.ttl
# ./rdf-data/131.ttl is valid!
# ---
#
# Validating: ./rdf-data/168.ttl
# ./rdf-data/168.ttl is valid!
# ---

# %% [markdown]
# ## Convert the graph into natural langauge sentences
#
# This is a very simple way to "serialize" a knowledge graph

# %%
from glob import glob
import rdflib
from tqdm import tqdm

# Define the namespace prefix (adjust if needed)
CO_LEARNING_NS = "http://example.org/co_learning#"


# Helper function to extract literals and form a sentence
def extract_literals_to_sentence(g, node):
    sentence_parts = []

    # Extract the literal values for the relevant properties
    for _, p, o in g.triples((node, None, None)):
        if (
            p.endswith("hasActor")
            or p.endswith("hasAction")
            or p.endswith("hasLocation")
            or p.endswith("hasObject")
        ):
            sentence_parts.append(str(o))  # Add the literal to the sentence parts

    # Join the sentence parts with a space
    return " ".join(sentence_parts)


# Function to convert a graph into three sentences
def graph_to_sentences(ttl_file: str):
    # Load the RDF graph
    g = rdflib.Graph()
    g.parse(ttl_file, format="turtle")

    situation_sentence = []
    action_human_sentence = []
    action_robot_sentence = []

    # Find instances of Situation, ActionHuman, and ActionRobot and generate sentences
    for s, rdf_type in g.subject_objects(rdflib.RDF.type):
        rdf_type_str = str(rdf_type)

        if rdf_type_str == CO_LEARNING_NS + "Situation":
            extracted = extract_literals_to_sentence(g, s)
            if extracted:
                situation_sentence.append(extracted)
        elif rdf_type_str == CO_LEARNING_NS + "ActionHuman":
            extracted = extract_literals_to_sentence(g, s)
            if extracted:
                action_human_sentence.append(extracted)
        elif rdf_type_str == CO_LEARNING_NS + "ActionRobot":
            extracted = extract_literals_to_sentence(g, s)
            if extracted:
                action_robot_sentence.append(extracted)

    situation_sentence = ", ".join(situation_sentence)
    action_human_sentence = ", ".join(action_human_sentence)
    action_robot_sentence = ", ".join(action_robot_sentence)

    return situation_sentence, action_human_sentence, action_robot_sentence


words = []

# Loop through all .ttl files and convert each to three sentences
for ttl_path in tqdm(sorted(glob("./rdf-data/*.ttl"))):
    situation, action_human, action_robot = graph_to_sentences(ttl_path)

    words.append(
        {
            "situation": situation,
            "action_human": action_human,
            "action_robot": action_robot,
        }
    )

    # Print or save the result (example prints for now)
    print(f"Graph: {ttl_path}")
    print(f"Situation: {situation}")
    print(f"ActionHuman: {action_human}")
    print(f"ActionRobot: {action_robot}")
    print("---\n")

# %% [markdown]
# ## Make bag-of-words feature vectors.
#
# I do this cuz I know that the vocabulary size is quite small

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# Combine the extracted sentences into a single string for each collaboration pattern
corpus = [
    f"{w['situation']}. {w['action_human']}. {w['action_robot']}."
    for w in words
]

# Use CountVectorizer to create the bag-of-words feature matrix
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corpus)

# Convert the feature matrix into a DataFrame for easy visualization
df_bow = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
df_bow

# %% [markdown]
# ## Clustering with K-means
#
# Play around with the number of clusters

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Perform K-Means clustering (adjust n_clusters based on your data)
n_clusters = 3  # You can experiment with different numbers of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(X)

# Get the cluster labels for each collaboration pattern
labels = kmeans.labels_

# Calculate the silhouette score to evaluate the clustering
silhouette_avg = silhouette_score(X, labels)
print(f"Silhouette Score for KMeans with {n_clusters} clusters: {silhouette_avg:.4f}")

# Add the cluster labels to the DataFrame for inspection
df_bow['Cluster'] = labels
df_bow

# %% [markdown]
# ## Visualize the clusters and points using PCA
#
# t-SNE might be better

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Reduce the dimensionality of the data using PCA for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X.toarray())

# Plot the clusters
plt.figure(figsize=(10, 7))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k', s=100)
plt.title(f"K-Means Clustering with {n_clusters} Clusters (PCA-reduced data)")
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.colorbar(label='Cluster')
plt.show()

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import pairwise_distances_argmin_min

# Step 3: Get the cluster centroids
centroids = kmeans.cluster_centers_

# Step 4: Find the row/point closest to the centroid for each cluster
closest, _ = pairwise_distances_argmin_min(centroids, X)

for i, index in enumerate(closest):
    print(
        f"Cluster {i}: Closest vector to centroid is at index {index}, which corresponds to: '{corpus[index]}'"
    )

# %%
closest
